# %% [markdown]
# # Exploratory Data Analysis of Customer Travel Preferences and Behaviours Objective

# %% [markdown]
# The primary objective of this Exploratory Data Analysis (EDA) is to uncover insights into customer demographics, behaviours, and preferences within the context of travel product offerings.

# %%
import pandas as pd

# %%
import numpy as np

# %%
project=pd.read_csv("Travel.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 project=pd.read_csv("Travel.csv")
#
# File c:\Users\gupta\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1024, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1011 kwds_defaults = _refine_defaults_read(
#    1012     dialect,
#    1013     delimiter,
#    (...)
#    1020     dtype_backend=dtype_backend,
#    1021 )
#    1022 kwds.update(kwds_defaults)
# -> 1024 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\gupta\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:618, in _read(filepath_or_buffer, kwds)
#     615 _validate_names(kwds.get("names", None))
#     617 # Create the parser.
# --> 618 parser = TextFileReader(filepath_or_buffer, **kwds)
#     620 if chunksize or iterator:
#     621     return parser
#
# File c:\Users\gupta\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1618, in TextFileReader.__init__(self, f, engine, **kwds)
#    1615     self.options["has_index_names"] = kwds["has_index_names"]
#    1617 self.handles: IOHandles | None = None
# -> 1618 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\gupta\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1878, in TextFileReader._make_engine(self, f, engine)
#    1876     if "b" not in mode:
#    1877         mode += "b"
# -> 1878 self.handles = get_handle(
#    1879     f,
#    1880     mode,
#    1881     encoding=self.options.get("encoding", None),
#    1882     compression=self.options.get("compression", None),
#    1883     memory_map=self.options.get("memory_map", False),
#    1884     is_text=is_text,
#    1885     errors=self.options.get("encoding_errors", "strict"),
#    1886     storage_options=self.options.get("storage_options", None),
#    1887 )
#    1888 assert self.handles is not None
#    1889 f = self.handles.handle
#
# File c:\Users\gupta\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Travel.csv'

# %%
project
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 project
#
# NameError: name 'project' is not defined

# %% [markdown]
# 1. What is the distribution of customerages, and how does age relate to product purchase (ProdTaken)?

# %%
distribution_age = dataset['Age'].value_counts().sort_index() 
distribution_age
# Out:
# Age
# 18.0     14
# 19.0     32
# 20.0     38
# 21.0     41
# 22.0     46
# 23.0     46
# 24.0     56
# 25.0     74
# 26.0    106
# 27.0    138
# 28.0    147
# 29.0    178
# 30.0    199
# 31.0    203
# 32.0    197
# 33.0    189
# 34.0    211
# 35.0    237
# 36.0    231
# 37.0    185
# 38.0    176
# 39.0    150
# 40.0    146
# 41.0    155
# 42.0    142
# 43.0    130
# 44.0    105
# 45.0    116
# 46.0    121
# 47.0     88
# 48.0     65
# 49.0     65
# 50.0     86
# 51.0     90
# 52.0     68
# 53.0     66
# 54.0     61
# 55.0     64
# 56.0     58
# 57.0     29
# 58.0     31
# 59.0     44
# 60.0     29
# 61.0      9
# Name: count, dtype: int64

# %%
relation_age_and_product_purchase = pd.pivot_table(dataset, values='ProdTaken', index='Age', aggfunc=np.sum)#this will make the pivot table of age and the number of product purchase by each age group
relation_of_age_with_product_purchase
# Out:
#       ProdTaken
# Age
# 18.0          8
# 19.0         21
# 20.0         25
# 21.0         23
# 22.0         15
# 23.0         13
# 24.0         18
# 25.0         20
# 26.0         37
# 27.0         30
# 28.0         26
# 29.0         57
# 30.0         48
# 31.0         41
# 32.0         40
# 33.0         40
# 34.0         44
# 35.0         34
# 36.0         27
# 37.0         24
# 38.0         15
# 39.0         14
# 40.0         23
# 41.0         24
# 42.0         20
# 43.0         10
# 44.0         17
# 45.0         18
# 46.0         11
# 47.0         12
# 48.0         11
# 49.0          9
# 50.0         12
# 51.0         17
# 52.0         14
# 53.0          8
# 54.0          2
# 55.0          7
# 56.0         12
# 57.0          5
# 58.0         11
# 59.0         12
# 60.0          1
# 61.0          0

# %% [markdown]
# 2. How does the type of contact(type of contact)influence the likelihood of purchasing a travel product?

# %%
project=pd.read_csv("Travel.csv")

# %%
project
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 4         200004          0   NaN     Self Enquiry         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
#           Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0           Salaried  Female                       3                3.0
# 1           Salaried    Male                       3                4.0
# 2        Free Lancer    Male                       3                4.0
# 3           Salaried  Female                       2                3.0
# 4     Small Business    Male                       2                3.0
# ...              ...     ...                     ...                ...
# 4883  Small Business    Male                       3                5.0
# 4884        Salaried    Male                       4                5.0
# 4885        Salaried  Female                       4                4.0
# 4886  Small Business    Male                       3                4.0
# 4887        Salaried    Male                       4                4.0
#
#      ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# 0            Deluxe                    3.0        Single            1.0
# 1            Deluxe                    4.0      Divorced            2.0
# 2             Basic                    3.0        Single            7.0
# 3             Basic                    3.0      Divorced            2.0
# 4             Basic                    4.0      Divorced            1.0
# ...             ...                    ...           ...            ...
# 4883         Deluxe                    4.0     Unmarried            2.0
# 4884          Basic                    3.0        Single            3.0
# 4885       Standard                    4.0       Married            7.0
# 4886          Basic                    3.0        Single            3.0
# 4887          Basic                    4.0     Unmarried            3.0
#
#       Passport  PitchSatisfactionScore  OwnCar  NumberOfChildrenVisiting  \
# 0            1                       2       1                       0.0
# 1            0                       3       1                       2.0
# 2            1                       3       0                       0.0
# 3            1                       5       1                       1.0
# 4            0                       5       1                       0.0
# ...        ...                     ...     ...                       ...
# 4883         1                       1       1                       1.0
# 4884         1                       3       1                       2.0
# 4885         0                       1       1                       3.0
# 4886         0                       5       0                       2.0
# 4887         1                       3       1                       2.0
#
#          Designation  MonthlyIncome
# 0            Manager        20993.0
# 1            Manager        20130.0
# 2          Executive        17090.0
# 3          Executive        17909.0
# 4          Executive        18468.0
# ...              ...            ...
# 4883         Manager        26576.0
# 4884       Executive        21212.0
# 4885  Senior Manager        31820.0
# 4886       Executive        20289.0
# 4887       Executive        24041.0
#
# [4888 rows x 20 columns]

# %%
influence_of_purchasing_and_travel_product_by_typeofcontact= pd.pivot_table(dataset, values='ProdTaken', index='TypeofContact', aggfunc=np.sum)#this will make the pivot table of Type of contact and the number of product purchase by each Type of contact
influence_of_a_purchasing_of_travel_product_by_typeofcontact
# Out:
#                  ProdTaken
# TypeofContact
# Company Invited        310
# Self Enquiry           607

# %% [markdown]
# 3. Is there a correlation between the city tier(citytier)and monthly income (monthly income) of customers?

# %%
checking_correlation_between_city_tier_and_monthly_income = pd.pivot_table(dataset, values='MonthlyIncome', index='CityTier', aggfunc=np.sum)
checking_correlation_between_city_tier_and_monthly_income
# Out:
#           MonthlyIncome
# CityTier
# 1            70839753.0
# 2             4564447.0
# 3            34546218.0

# %% [markdown]
# 4. What is the average duration of a pitch (duration of pitch)for customers who purchased a product versus those who did not?

# %%
duration_avergeof_pitch = pd.pivot_table(dataset, values='DurationOfPitch', index='ProductPitched', aggfunc='mean')
duration_avergeof_pitch
# Out:
#                 DurationOfPitch
# ProductPitched
# Basic                 15.194834
# Deluxe                15.935839
# King                  12.100000
# Standard              15.986505
# Super Deluxe          16.230994

# %% [markdown]
# 5. How do occupation types(occupation)distribute among customers,and is there an occupation type that is more likely to purchase a travel product?

# %%
occupation_of_distribution_among_customers=dataset.groupby("Occupation")['CustomerID'].count()
occupation_of_distribution_among_customers
# Out:
# Occupation
# Free Lancer          2
# Large Business     434
# Salaried          2368
# Small Business    2084
# Name: CustomerID, dtype: int64

# %%
checking_is_there_is_any_occupation_that_is_more_likely_to_purchase_a_travel_product=dataset.groupby("Occupation")['ProdTaken'].mean()
checking_is_there_is_any_occupation_that_is_more_likely_to_purchase_a_travel_product
# Out:
# Occupation
# Free Lancer       1.000000
# Large Business    0.276498
# Salaried          0.174831
# Small Business    0.184261
# Name: ProdTaken, dtype: float64

# %%
project=pd.read_csv("Travel.csv")

# %%
project
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 4         200004          0   NaN     Self Enquiry         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
#           Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0           Salaried  Female                       3                3.0
# 1           Salaried    Male                       3                4.0
# 2        Free Lancer    Male                       3                4.0
# 3           Salaried  Female                       2                3.0
# 4     Small Business    Male                       2                3.0
# ...              ...     ...                     ...                ...
# 4883  Small Business    Male                       3                5.0
# 4884        Salaried    Male                       4                5.0
# 4885        Salaried  Female                       4                4.0
# 4886  Small Business    Male                       3                4.0
# 4887        Salaried    Male                       4                4.0
#
#      ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# 0            Deluxe                    3.0        Single            1.0
# 1            Deluxe                    4.0      Divorced            2.0
# 2             Basic                    3.0        Single            7.0
# 3             Basic                    3.0      Divorced            2.0
# 4             Basic                    4.0      Divorced            1.0
# ...             ...                    ...           ...            ...
# 4883         Deluxe                    4.0     Unmarried            2.0
# 4884          Basic                    3.0        Single            3.0
# 4885       Standard                    4.0       Married            7.0
# 4886          Basic                    3.0        Single            3.0
# 4887          Basic                    4.0     Unmarried            3.0
#
#       Passport  PitchSatisfactionScore  OwnCar  NumberOfChildrenVisiting  \
# 0            1                       2       1                       0.0
# 1            0                       3       1                       2.0
# 2            1                       3       0                       0.0
# 3            1                       5       1                       1.0
# 4            0                       5       1                       0.0
# ...        ...                     ...     ...                       ...
# 4883         1                       1       1                       1.0
# 4884         1                       3       1                       2.0
# 4885         0                       1       1                       3.0
# 4886         0                       5       0                       2.0
# 4887         1                       3       1                       2.0
#
#          Designation  MonthlyIncome
# 0            Manager        20993.0
# 1            Manager        20130.0
# 2          Executive        17090.0
# 3          Executive        17909.0
# 4          Executive        18468.0
# ...              ...            ...
# 4883         Manager        26576.0
# 4884       Executive        21212.0
# 4885  Senior Manager        31820.0
# 4886       Executive        20289.0
# 4887       Executive        24041.0
#
# [4888 rows x 20 columns]

# %% [markdown]
# 6. Are there any gender-based preferences for the type of product pitched (ProductPitched)?

# %%
checking_is_any_gender_based_preference_for_the_product_pitched=pd.pivot_table(dataset, values='ProductPitched', index='Gender', aggfunc='count')
checking_is_any_gender_based_preference_for_the_product_pitched
# Out:
#          ProductPitched
# Gender
# Fe Male             155
# Female             1817
# Male               2916

# %% [markdown]
# 7. What is the relationship between the number of trips(number of trips)taken by a customer and their likelihood to purchase a new travel product?

# %%
relation_between_the_number_of_trips_with_product_taken=pd.pivot_table(dataset,values='ProdTaken',index='NumberOfTrips',aggfunc='mean')
relation_between_the_number_of_trips_with_product_taken
# Out:
#                ProdTaken
# NumberOfTrips
# 1.0             0.180645
# 2.0             0.204235
# 3.0             0.201112
# 4.0             0.127615
# 5.0             0.135371
# 6.0             0.198758
# 7.0             0.284404
# 8.0             0.276190
# 19.0            1.000000
# 20.0            1.000000
# 21.0            0.000000
# 22.0            0.000000

# %% [markdown]
# 8. Does having a passport(passport)correlate with a higher number of trips taken or a higher likelihood of purchasing a travel product?

# %%
higher_number_trips_and_passport = dataset.groupby('Passport')['NumberOfTrips'].mean()
higher_number_trips_and_passport
# Out:
# Passport
# 0    3.221165
# 1    3.273844
# Name: NumberOfTrips, dtype: float64

# %%
higher_likelihood_purchase_and_passport = dataset.groupby('Passport')['ProdTaken'].mean()
higher_likelihood_purchase_and_passport
# Out:
# Passport
# 0    0.122908
# 1    0.347398
# Name: ProdTaken, dtype: float64

# %% [markdown]
# 9. How satisfied are customers with the pitch (pitch satisfaction score),and does this satisfaction influence product purchase?

# %%
satisfaction_of_customer_to_pitch=dataset.groupby('PitchSatisfactionScore')['CustomerID'].count()
satisfaction_of_customer_to_pitch
# Out:
# PitchSatisfactionScore
# 1     942
# 2     586
# 3    1478
# 4     912
# 5     970
# Name: CustomerID, dtype: int64

# %%
checking_satisfaction_of_customer_with_pitch_influenced_product_purchase=dataset.groupby('PitchSatisfactionScore')['ProdTaken'].mean()
checking_satisfaction_of_customer_with_pitch_influenced_product_purchase
# Out:
# PitchSatisfactionScore
# 1    0.152866
# 2    0.150171
# 3    0.213802
# 4    0.177632
# 5    0.216495
# Name: ProdTaken, dtype: float64

# %% [markdown]
# 10. Among customers with children (number of children visiting), how does the number of children impact travel product purchases?

# %%
number_of_children_visiting_product_purchases=dataset.groupby('NumberOfChildrenVisiting')['ProdTaken'].mean()
number_of_children_visiting_product_purchases
# Out:
# NumberOfChildrenVisiting
# 0.0    0.186691
# 1.0    0.188462
# 2.0    0.189513
# 3.0    0.203077
# Name: ProdTaken, dtype: float64

# %% [markdown]
# 11. Gender preferences for product types: how does gender influence the preference for different types of travel products pitched (product pitched)?

# %%
product_gender_preferences = pd.pivot_table(dataset, index='Gender', columns='ProductPitched', aggfunc='size', fill_value=0)
product_gender_preferences
# Out:
# ProductPitched  Basic  Deluxe  King  Standard  Super Deluxe
# Gender
# Fe Male             4      83     0        63             5
# Female            676     641    82       263           155
# Male             1162    1008   148       416           182

# %% [markdown]
# 12. Impact of marital status on travel preferences: does marital status affect the choice of travel product, and if so, how do different marital statuses correlate with product purchases (prod taken)?

# %%
marital_status_product_preferences = pd.pivot_table(dataset, index='MaritalStatus', columns='ProductPitched', aggfunc='size', fill_value=0)
marital_status_product_preferences
# Out:
# ProductPitched  Basic  Deluxe  King  Standard  Super Deluxe
# MaritalStatus
# Divorced          332     336    52       142            88
# Married           816     852   126       380           166
# Single            511     221    52        50            82
# Unmarried         183     323     0       170             6

# %%
marital_status_purchase_and_correlation = dataset.groupby('MaritalStatus')['ProdTaken'].mean()
marital_status_purchase_and_correlation
# Out:
# MaritalStatus
# Divorced     0.130526
# Married      0.139316
# Single       0.331878
# Unmarried    0.243402
# Name: ProdTaken, dtype: float64

# %% [markdown]
# 13. Relationship between number of children and travel product interest: how does the number of children visiting (number of children visiting) impact the likelihood of purchasing a travel product?

# %%
children_visiting_purchase_and_correlation = dataset.groupby('NumberOfChildrenVisiting')['ProdTaken'].mean()
children_visiting_purchase_and_correlation
# Out:
# NumberOfChildrenVisiting
# 0.0    0.186691
# 1.0    0.188462
# 2.0    0.189513
# 3.0    0.203077
# Name: ProdTaken, dtype: float64

# %% [markdown]
# 14. Influence of owning a car on travel decisions: is there a correlation between owning a car (own car) and the number of trips taken (number of trips) or the type of travel product purchased?

# %%
correlation_own_car_by_trips=dataset.groupby('OwnCar')['NumberOfTrips'].mean()
correlation_own_car_by_trips
# Out:
# OwnCar
# 0    3.264349
# 1    3.219346
# Name: NumberOfTrips, dtype: float64

# %%
own_car_purchase_and_correlation = dataset.groupby('OwnCar')['ProdTaken'].mean()
own_car_purchase_and_correlation
# Out:
# OwnCar
# 0    0.193966
# 1    0.184697
# Name: ProdTaken, dtype: float64

# %% [markdown]
# 15. Income level and product choice: how does the monthly income (monthly income) of customers influence their choice of travel products, and is there a preferred product for different income levels?

# %%
about_income_product_preferences = pd.pivot_table(dataset, index='MonthlyIncome', columns='ProductPitched', aggfunc='size', fill_value=0)
about_income_product_preferences
# Out:
# ProductPitched  Basic  Deluxe  King  Standard  Super Deluxe
# MonthlyIncome
# 1000.0              0       1     0         0             0
# 4678.0              0       1     0         0             0
# 16009.0             2       0     0         0             0
# 16051.0             2       0     0         0             0
# 16052.0             2       0     0         0             0
# ...               ...     ...   ...       ...           ...
# 38621.0             0       0     2         0             0
# 38651.0             0       0     2         0             0
# 38677.0             0       0     2         0             0
# 95000.0             1       0     0         0             0
# 98678.0             1       0     0         0             0
#
# [2475 rows x 5 columns]
